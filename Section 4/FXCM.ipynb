# %%
import fxcmpy

# %%
TOKEN = "input your fxcm token here"

# %%
con = fxcmpy.fxcmpy(access_token=TOKEN, log_level='error')

# %%
con.get_instruments()
# Out:
# ['EUR/USD',
#  'USD/JPY',
#  'GBP/USD',
#  'USD/CHF',
#  'EUR/CHF',
#  'AUD/USD',
#  'USD/CAD',
#  'NZD/USD',
#  'EUR/GBP',
#  'EUR/JPY',
#  'GBP/JPY',
#  'CHF/JPY',
#  'GBP/CHF',
#  'EUR/AUD',
#  'EUR/CAD',
#  'AUD/CAD',
#  'AUD/JPY',
#  'CAD/JPY',
#  'NZD/JPY',
#  'GBP/CAD',
#  'GBP/NZD',
#  'GBP/AUD',
#  'AUD/NZD',
#  'USD/SEK',
#  'EUR/SEK',
#  'EUR/NOK',
#  'USD/NOK',
#  'USD/MXN',
#  'AUD/CHF',
#  'EUR/NZD',
#  'USD/ZAR',
#  'USD/HKD',
#  'ZAR/JPY',
#  'USD/TRY',
#  'EUR/TRY',
#  'NZD/CHF',
#  'CAD/CHF',
#  'NZD/CAD',
#  'TRY/JPY',
#  'AUS200',
#  'ESP35',
#  'FRA40',
#  'GER30',
#  'HKG33',
#  'JPN225',
#  'NAS100',
#  'SPX500',
#  'UK100',
#  'US30',
#  'Copper',
#  'CHN50',
#  'EUSTX50',
#  'USDOLLAR',
#  'USOil',
#  'UKOil',
#  'SOYF',
#  'NGAS',
#  'Bund',
#  'XAU/USD',
#  'XAG/USD']

# %%
df = con.get_candles('USD/JPY', period='m1', number=250)

# %%
df.head()
# Out:
#                      bidopen  bidclose  bidhigh   bidlow  askopen  askclose  \
# date
# 2018-08-14 08:44:00  111.050   111.054  111.063  111.047  111.063   111.066
# 2018-08-14 08:45:00  111.055   111.062  111.063  111.048  111.067   111.074
# 2018-08-14 08:46:00  111.062   111.068  111.090  111.054  111.074   111.080
# 2018-08-14 08:47:00  111.067   111.071  111.079  111.053  111.079   111.084
# 2018-08-14 08:48:00  111.072   111.051  111.078  111.051  111.085   111.065
#
#                      askhigh   asklow  tickqty
# date
# 2018-08-14 08:44:00  111.076  111.058      191
# 2018-08-14 08:45:00  111.075  111.061      231
# 2018-08-14 08:46:00  111.103  111.067      429
# 2018-08-14 08:47:00  111.091  111.065      270
# 2018-08-14 08:48:00  111.091  111.064      192

# %%
from pylab import plt
plt.style.use('seaborn')
# %matplotlib inline
df['askclose'].plot(figsize=(10, 6));

# %%
plots = df[['bidclose', 'tickqty']].plot(subplots=True, figsize=(10, 10))
plt.show()

# %%
import pandas as pd
df['ma50'] = pd.rolling_mean(df['bidclose'], 50)
df['ma200'] = pd.rolling_mean(df['bidclose'], 200)
plots = df[['bidclose', 'ma50', 'ma200']].plot(subplots=False, figsize=(10, 4))
plt.show()
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,center=False).mean()
#
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=200,center=False).mean()
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df = con.get_candles('USD/JPY', period='m1',
                       columns=['asks'], number=50)

# %%
df.head()
# Out:
#                      askopen  askclose  askhigh   asklow
# date
# 2018-08-14 12:05:00  110.848   110.848  110.854  110.846
# 2018-08-14 12:06:00  110.848   110.829  110.848  110.829
# 2018-08-14 12:07:00  110.828   110.797  110.834  110.786
# 2018-08-14 12:08:00  110.797   110.812  110.818  110.797
# 2018-08-14 12:09:00  110.813   110.825  110.825  110.811

# %%
df.plot(figsize=(10, 6), lw=0.8);
